# %%
import mpld3
mpld3.enable_notebook()
import pandas as pd
import numpy as np

from matplotlib import pyplot as plt
#%matplotlib inline
# %matplotlib notebook

# %%
"""
It seems that in some cases it helps to repeat the setting of the notebook backend, i.e. 
call it(%matplotlib notebook) twice like

"""

# %matplotlib notebook
# %matplotlib notebook
x=np.arange(0,np.pi,np.pi/100)
y=np.sin(x)
plt.plot(x,y)
# Out:
# <img src="data:image/png;base64,..." width="431.49606947254676">

# %%
# %matplotlib inline
mpld3.enable_notebook()
x=np.arange(0,np.pi,np.pi/100)
y=np.sin(x)
plt.plot(x,y)
